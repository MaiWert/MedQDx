# %% [markdown]
# # MedQDx Banchmark Creation
#
# This script iterates over each patient case in a DataFrame to build a zero-shot diagnostic benchmark:
# 1. For each case, the “doctor” LLM (GPT-4.1) receives only 50% of the full case and asks a first question.
# 2. The “patient” LLM (GPT-4o-mini) answers based on the 100% case.
# 3. After each answer, GPT-4.1 attempts a diagnosis and we record the similarity to the ground-truth disease.
# 4. The process repeats for a second and third round of questioning, each time appending question, answer, diagnosis, and similarity.
# 5. Finally, the script outputs a benchmark table with columns:
#    prognosis, symptoms, 100% case, 80% case, 50% case,
#    Question_1, Answer_1, Diagnosis_1, Similarity_1,
#    Question_2, Answer_2, Diagnosis_2, Similarity_2,
#    Question_3, Answer_3, Diagnosis_3, Similarity_3
#
# This provides a comprehensive MedQDx zero-shot performance benchmark.

# %%
# !pip install openai
# !pip install -q transformers accelerate bitsandbytes
# !pip install openai --upgrade
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.82.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.82.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
import os
import re
import torch
import openai
import pandas as pd
from tqdm import tqdm
from openai import AzureOpenAI
from google.colab import files
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Doctor LLM - GPT 4.1

# %%
DoctorGPTclient = AzureOpenAI(
    api_version    = "2024-12-01-preview",
    azure_endpoint = "MedQDx_ENDPOINT",
    api_key        = "MedQDx__API_key",
)

# %% [markdown]
# ## Generating doctor question

# %%
def GPT_doctor(prompt, max_tokens=2000):
    response = DoctorGPTclient.chat.completions.create(
    messages=[
        {"role": "system","content": "You are a medical doctor."},
        {"role": "user","content": prompt}
    ],
    max_completion_tokens=800,
    temperature=1.0,
    top_p=1.0,
    frequency_penalty=0.0,
    presence_penalty=0.0,
    model='gpt-4.1')

    return response.choices[0].message.content

# %% [markdown]
# ## Updating prompt for doctors questions

# %%
def build_first_doctor_question_prompt(case_text):
    prompt = f"""
You are a medical doctor conducting a diagnostic interview with a patient.
You have received partial information about the case.
Your goal is to ask exactly **ONE** relevant, case-specific question that will enable a more precise diagnosis.

Rules:
- Output exactly one question as a single, complete sentence.
- The question must be a single line, ending in ‘?’
- The question must be specific to the case.
- Do not include any explanations, reasoning, or additional text.
- Do not provide a diagnosis or suggest treatments in the question.
- Base the question solely on the provided partial case information.

Partial case Information:
{case_text}

### User: What is the first best diagnostic question you want to ask the patient (one question)?
### Assistant:
"""
    return prompt.strip()

# %%
def build_doctor_question_prompt(case_text: str, history: str, previous_questions: list) -> str:
    """
    Constructs a prompt for the doctor to ask exactly one new question,
    ensuring it does NOT repeat any question in previous_questions.
    """

    # # If there are previous questions, format them as bullet points,
    #    so the model can see what’s already been asked and avoid repetition
    if previous_questions:
        prev_section = "Previous questions asked (do NOT repeat any of these):\n"
        for q in previous_questions:
            prev_section += f"- {q}\n"
    else:
        prev_section = ""  # Leave empty if no prior questions

    prompt = f"""
You are a medical doctor conducting a diagnostic interview with a patient.
You have received partial information about the case and the past conversation with the patient.
Your goal is to ask exactly **ONE** new, relevant, case-specific question that will enable a more precise diagnosis.
Ensure that this new question is **word-for-word different** from all previous questions.

Rules:
- Output **ONLY ONE** question as a single, complete sentence ending with a question mark.
- Do NOT include any explanations, reasoning, or additional text—only the question itself.
- The question must be a single line, ending in ‘?’
- Do NOT provide a diagnosis or suggest treatments.
- Base the question on the partial case information and past conversation with the patient.
- ask new question to obtain additional information for better diasnosis.
- If the patient responded "I'm not sure," ask a broader or differently phrased question to elicit new information.

Partial case Information::
{case_text}

Past Conversation with the patient:
{history}

{prev_section}

### User:Next, output one NEW question you would ask the patient:
### Assistant:
"""
    return prompt.strip()

# %% [markdown]
# # Patient LLM - GPT-4o Mini

# %%
# !pip install azure-ai-inference
# Out:
# Requirement already satisfied: azure-ai-inference in /usr/local/lib/python3.11/dist-packages (1.0.0b9)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from azure-ai-inference) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/lib/python3.11/dist-packages (from azure-ai-inference) (1.34.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from azure-ai-inference) (4.13.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure-ai-inference) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2025.4.26)

# %%
endpoint       = "MedQDx_ENDPOINT"
api_key        = "MedQDx__API_key"
api_version    = "2024-12-01-preview"
deployment     = "gpt-4o-mini"

client = AzureOpenAI(
    api_version    = api_version,
    azure_endpoint = endpoint,
    api_key        = api_key,
)

# %%
def build_patient_answer_prompt(Full_case, doctor_question):
    prompt = (
                f"""You are a patient who has provided a detailed case history.  Your task is to answer **only** the doctor’s question, using information from the case description below.  Do not add, remove, or invent any details.  Answer in first person, as a realistic patient would.

–––––––––––––––––––––––––––––––––––––––––––––––––––––
FULL PATIENT CASE:
{Full_case}
–––––––––––––––––––––––––––––––––––––––––––––––––––––

DOCTOR’S QUESTION:
{doctor_question}

PATIENT INSTRUCTIONS:
•  Read the “FULL PATIENT CASE” carefully.
•  When you answer, respond as “the patient” in first person (e.g., “I have been feeling…,” “Yes, I have noticed…”).
•  Use only information that appears in the case description.
•  If the doctor’s question refers to a symptom or detail that is **not** in the case, reply honestly: “No,” or “I have not noticed that.”
•  Keep your answer concise—just those facts from the case that directly address the question.
•  Do **not** volunteer any additional background, diagnosis, or speculation.

PATIENT RESPONSE:
"""
    )
    return prompt.strip()

# %% [markdown]
# ## Generating patient answer to doctor question

# %%
def patient_answer(Full_case, doctor_question):
    prompt = build_patient_answer_prompt(Full_case, doctor_question)
    response = client.chat.completions.create(
        model= deployment,
        messages=[
            {"role": "system", "content": "You are a patient answering your doctor's questions based on the symptoms that your case presents."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=300,
        temperature=0.8,
        top_p=0.95
    )
    return response.choices[0].message.content.strip()

# %% [markdown]
# # Doctor diagnosis (GPT 4.1)

# %% [markdown]
# ## Creating an updated prompt for doctor diagnosis and diagnosing

# %%
def build_doctor_diagnosis_prompt(case_text, history):
    """
    Creates a prompt for the doctor to provide a diagnosis based on case and history.
    """
    prompt = f"""
***You are a medical doctor***. Your task is to provide a single most likely diagnosis based on the partial case information and the past conversation with the patient.

Rules:
- Analyze the case details and patient responses.
- Use clinical reasoning to determine the most probable diagnosis.
- Output ONLY the name of the disease or condition using correct medical term (e.g., Pneumonia, Hypoglycemia).
- Do not include any notes, explanations, disclaimers, or additional text.
- Do not output symbols like ### or other placeholders.
- Do not repeat on the case symptoms
- Do not repeat on the patient answers

Case Information:
{case_text}

Conversation History:
{history}

### User: The patient diagnosis is:
### Assistant:
"""
    return prompt.strip()

# %% [markdown]
# ## Checking the similarity between the doctor's diagnosis and a real disease

# %%
embeddings_client = openai.AzureOpenAI(
    api_key="MedQDx_API_key",
    azure_endpoint="MedQDx_ENDPOINT",
    api_version="2024-12-01-preview"
)

def get_embedding(text, embeddings_client):
    """
    Gets the embedding for a given text using Azure OpenAI.
    """
    try:
        response = embeddings_client.embeddings.create(
            input=text,
            model="text-embedding-3-small"
        )
        return response.data[0].embedding
    except Exception as e:
        print(f"Error generating embedding: {e}")
        return None

# %%
def compute_similarity(pred, label, embeddings_client):
    """
    Computes cosine similarity between predicted and ground-truth diagnosis.
    """
    if not pred or not label:
        return 0.0
    emb1 = get_embedding(pred, embeddings_client)
    emb2 = get_embedding(label, embeddings_client)
    if emb1 is None or emb2 is None:
        return 0.0
    return cosine_similarity([emb1], [emb2])[0][0]

# %% [markdown]
# # Uploading CSV and prepare dataframe

# %%
file_path = '/content/drive/MyDrive/NLP/patient_cases.csv'

# %%
df = pd.read_csv(file_path)

for i in range(1, 4):
    df[f"Question_{i}"] = ""
    df[f"Answer_{i}"] = ""
    df[f"Diagnosis_{i}"] = ""
    df[f"Similarity_{i}"] = None

# %% [markdown]
# # Banckmark creation

# %%
for idx, row in df.iterrows():
    case_text = row['50% Case']
    Full_case = row['100% Case']
    gt_prognosis = row["prognosis"]
    history = ""
    previous_questions = []

    print(f"\n====== Start Case {idx} ======")

    for round_num in range(1, 4):
        print(f"\n--- Round {round_num} ---")
        # Doctor asks question
        if round_num == 1:
            doctor_q_prompt = build_first_doctor_question_prompt(case_text)
        else:
            doctor_q_prompt = build_doctor_question_prompt(case_text, history, previous_questions)
        doctor_question = GPT_doctor(doctor_q_prompt)
        previous_questions.append(doctor_question)
        print(f"Doctor Question (round {round_num}): {doctor_question}")
        df.at[idx, f"Question_{round_num}"] = doctor_question

        # Patient answers
        patient_ans = patient_answer(Full_case, doctor_question)
        print(f"Patient Answer (round {round_num}): {patient_ans}")
        df.at[idx, f"Answer_{round_num}"] = patient_ans

        # Updating history
        history += f"Doctor: {doctor_question}\nPatient: {patient_ans}\n"

        # Doctor provides diagnosis
        prompt = build_doctor_diagnosis_prompt(case_text, history)
        doctor_diagnosis = GPT_doctor(prompt)
        print(f"Doctor Diagnosis (round {round_num}): {doctor_diagnosis}")
        df.at[idx, f"Diagnosis_{round_num}"] = doctor_diagnosis

        # Computing similarity
        similarity = compute_similarity(doctor_diagnosis, gt_prognosis, embeddings_client)
        print(f"Similarity (round {round_num}): {similarity}")
        df.at[idx, f"Similarity_{round_num}"] = similarity


# Final save
output_path = "MedQDx_benchmark.csv"
df.to_csv(output_path, index=False)
files.download(output_path)
# Out:
# ====== Start Case 0 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you experienced a sore throat or any difficulty swallowing recently?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Infectious mononucleosis
# Similarity (round 1): 0.3970650055518463
#
# --- Round 2 ---
# Doctor Question (round 2): Have you had any recent contact with individuals who were sick or had similar symptoms?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Infectious mononucleosis
# Similarity (round 2): 0.3970650055518463
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently traveled outside your usual area or been exposed to animals?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Infectious mononucleosis
# Similarity (round 3): 0.3970650055518463
#
# ====== Start Case 1 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any recent changes in your blood pressure, such as episodes of high or low blood pressure?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Hypoglycemia
# Similarity (round 1): 1.0000000000000004
#
# --- Round 2 ---
# Doctor Question (round 2): Have you been experiencing any chest pain, shortness of breath, or dizziness along with your other symptoms?
# Patient Answer (round 2): No, I have not noticed any chest pain, shortness of breath, or dizziness.
# Doctor Diagnosis (round 2): Hypoglycemia
# Similarity (round 2): 1.0000000000000004
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent changes in your eating habits, appetite, or weight?
# Patient Answer (round 3): Yes, I have noted excessive hunger recently.
# Doctor Diagnosis (round 3): Hypoglycemia
# Similarity (round 3): 1.0000000000000004
#
# ====== Start Case 2 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any shortness of breath, especially when lying down or during physical activity?
# Patient Answer (round 1): No, I have not noticed any shortness of breath, especially when lying down or during physical activity.
# Doctor Diagnosis (round 1): Chronic venous insufficiency
# Similarity (round 1): 0.5897960963950912
#
# --- Round 2 ---
# Doctor Question (round 2): Have you observed any changes in the amount or frequency of your urination recently?
# Patient Answer (round 2): I have not noticed any changes in the amount or frequency of my urination recently.
# Doctor Diagnosis (round 2): Chronic venous insufficiency
# Similarity (round 2): 0.5897960963950912
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent changes in your diet or fluid intake?
# Patient Answer (round 3): I have not noticed any recent changes in my diet or fluid intake.
# Doctor Diagnosis (round 3): Chronic venous insufficiency
# Similarity (round 3): 0.5897960963950912
#
# ====== Start Case 3 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in the color of your urine or stool recently?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Cholestasis
# Similarity (round 1): 0.8378455755150633
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any recent weight loss without trying?
# Patient Answer (round 2): Yes, I have noticed a significant loss of appetite, and I can barely finish my meals.
# Doctor Diagnosis (round 2): Cholestasis
# Similarity (round 2): 0.8378455755150633
#
# --- Round 3 ---
# Doctor Question (round 3): Can you describe exactly where in your abdomen you feel the discomfort and whether it comes and goes or is constant?
# Patient Answer (round 3): I feel the discomfort in the right upper quadrant of my abdomen. It is persistent and does not come and go; it is constant.
# Doctor Diagnosis (round 3): Cholestasis
# Similarity (round 3): 0.8378455755150633
#
# ====== Start Case 4 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Can you describe exactly when you first noticed the yellowing of your skin and whether it has become more pronounced over time?
# Patient Answer (round 1): I first noticed the yellowing of my skin about two weeks ago, and it has become more pronounced over time.
# Doctor Diagnosis (round 1): Autoimmune hepatitis
# Similarity (round 1): 0.5572622402620211
#
# --- Round 2 ---
# Doctor Question (round 2): Have you observed any changes in the color of your urine or stool recently?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Autoimmune hepatitis
# Similarity (round 2): 0.5572622402620211
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any itching of your skin along with the yellowing?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Autoimmune hepatitis
# Similarity (round 3): 0.5572622402620211
#
# ====== Start Case 5 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any yellowing of your skin or eyes recently?
# Patient Answer (round 1): Yes, I have noticed a yellowish discoloration of my skin and eyes recently.
# Doctor Diagnosis (round 1): Acute viral hepatitis
# Similarity (round 1): 0.5795651812135696
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any itching of your skin or unusual bruising or bleeding lately?
# Patient Answer (round 2): Yes, I have been experiencing intense itching, particularly on my arms and legs. I have not noticed any unusual bruising or bleeding.
# Doctor Diagnosis (round 2): Acute viral hepatitis
# Similarity (round 2): 0.5795651812135696
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent nausea or vomiting, or noticed any changes in the color of your stools?
# Patient Answer (round 3): I have not noticed any recent nausea or vomiting, and I have not mentioned any changes in the color of my stools.
# Doctor Diagnosis (round 3): Acute viral hepatitis
# Similarity (round 3): 0.5795651812135696
#
# ====== Start Case 6 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any recent changes in your weight, such as unexplained weight loss or gain?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Hyperthyroidism
# Similarity (round 1): 1.0000000000000004
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any episodes of heart palpitations or a racing heartbeat lately?
# Patient Answer (round 2): Yes, I have noticed a fast heart rate, especially during stressful situations.
# Doctor Diagnosis (round 2): Hyperthyroidism
# Similarity (round 2): 1.0000000000000004
#
# --- Round 3 ---
# Doctor Question (round 3): Have you observed any changes in your energy levels throughout the day, such as feeling more fatigued in the morning or evening?
# Patient Answer (round 3): I have been experiencing significant fatigue that interferes with my daily activities, but I haven't specifically noted if I'm more fatigued in the morning or evening.
# Doctor Diagnosis (round 3): Hyperthyroidism
# Similarity (round 3): 1.0000000000000004
#
# ====== Start Case 7 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in the color of your urine or stool, or any yellowing of your skin or eyes?
# Patient Answer (round 1): I have not noticed any changes in the color of my urine or stool, or any yellowing of my skin or eyes.
# Doctor Diagnosis (round 1): Viral gastroenteritis
# Similarity (round 1): 0.36081839186263753
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any episodes of vomiting or diarrhea along with your nausea and abdominal pain?
# Patient Answer (round 2): Yes, I have experienced persistent vomiting and a few episodes of diarrhea along with my nausea and abdominal pain.
# Doctor Diagnosis (round 2): Acute gastroenteritis
# Similarity (round 2): 0.37144875208367373
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently traveled anywhere or been in contact with anyone who was ill?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Viral gastroenteritis
# Similarity (round 3): 0.36081839186263753
#
# ====== Start Case 8 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any stiffness in your knee when you first get up in the morning, and if so, how long does it last?
# Patient Answer (round 1): Yes, I have noticed stiffness in my knees when I first get up in the morning. The stiffness lasts for a while, but it improves slightly as the day progresses.
# Doctor Diagnosis (round 1): Osteoarthritis
# Similarity (round 1): 1.0
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any clicking, popping, or locking sensations in your knee during movement?
# Patient Answer (round 2): I have not noticed any clicking, popping, or locking sensations in my knee during movement.
# Doctor Diagnosis (round 2): Osteoarthritis
# Similarity (round 2): 1.0
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent injuries or trauma to your knee or leg?
# Patient Answer (round 3): No, I have not noticed any recent injuries or trauma to my knee or leg.
# Doctor Diagnosis (round 3): Osteoarthritis
# Similarity (round 3): 1.0
#
# ====== Start Case 9 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any new rashes, bumps, or marks on your skin since your camping trip?
# Patient Answer (round 1): Yes, I have noticed a skin rash characterized by red, raised bumps on my abdomen and back since my camping trip.
# Doctor Diagnosis (round 1): Cutaneous larva migrans
# Similarity (round 1): 0.13929493282026256
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any nausea, vomiting, or changes in your bowel movements along with the stomach pain?
# Patient Answer (round 2): No, I have not noticed any nausea, vomiting, or changes in my bowel movements along with the stomach pain.
# Doctor Diagnosis (round 2): Cutaneous larva migrans
# Similarity (round 2): 0.13929493282026256
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any fevers, chills, or night sweats since your symptoms began?
# Patient Answer (round 3): No, I have not noticed any fevers, chills, or night sweats since my symptoms began.
# Doctor Diagnosis (round 3): Contact dermatitis
# Similarity (round 3): 0.3362602635642786
#
# ====== Start Case 10 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Do you have any sensitivity to light or sound along with your headache?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Vestibular migraine
# Similarity (round 1): 0.49582156796400934
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any changes in your vision, such as blurriness or seeing spots?
# Patient Answer (round 2): No, I have not noticed any changes in my vision, such as blurriness or seeing spots.
# Doctor Diagnosis (round 2): Vestibular migraine
# Similarity (round 2): 0.49582156796400934
#
# --- Round 3 ---
# Doctor Question (round 3): Have you ever had a headache like this before, or is this your first time experiencing these symptoms?
# Patient Answer (round 3): This is my first time experiencing these symptoms.
# Doctor Diagnosis (round 3): Vestibular migraine
# Similarity (round 3): 0.49582156796400934
#
# ====== Start Case 11 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any yellowing of your skin or eyes recently?
# Patient Answer (round 1): Yes, I have noticed yellowing of my skin.
# Doctor Diagnosis (round 1): Acute viral hepatitis
# Similarity (round 1): 0.2936199185043479
#
# --- Round 2 ---
# Doctor Question (round 2): Have you observed any changes in the color of your urine or stool?
# Patient Answer (round 2): Yes, I have noticed that my urine has become dark, resembling tea. I have not observed any changes in the color of my stool.
# Doctor Diagnosis (round 2): Acute viral hepatitis
# Similarity (round 2): 0.2936199185043479
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently experienced any unintentional weight loss or loss of appetite?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Acute viral hepatitis
# Similarity (round 3): 0.2936199185043479
#
# ====== Start Case 12 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any swelling, redness, or morning stiffness in your hand joints that lasts longer than 30 minutes?
# Patient Answer (round 1): Yes, I have noticed swelling and redness around my nail beds, but I have not specifically mentioned morning stiffness in my hand joints lasting longer than 30 minutes.
# Doctor Diagnosis (round 1): Psoriatic arthritis
# Similarity (round 1): 0.6813099839042092
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any changes in your finger or toenails, such as pitting, thickening, or separation from the nail bed?
# Patient Answer (round 2): Yes, I have noticed small dents in my nails and experienced inflammatory changes around my nail beds, including redness and swelling.
# Doctor Diagnosis (round 2): Psoriatic arthritis
# Similarity (round 2): 0.6813099839042092
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any pain, stiffness, or discomfort in other joints besides your hands, such as your knees, ankles, or lower back?
# Patient Answer (round 3): Yes, I have persistent joint pain in my knees.
# Doctor Diagnosis (round 3): Psoriatic arthritis
# Similarity (round 3): 0.6813099839042092
#
# ====== Start Case 13 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any increased thirst or drinking more fluids than usual during the past few months?
# Patient Answer (round 1): Yes, I have noticed that I am drinking more fluids than usual.
# Doctor Diagnosis (round 1): Diabetes mellitus
# Similarity (round 1): 0.7888775053383126
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any blurry vision or changes in your eyesight recently?
# Patient Answer (round 2): Yes, I have noticed blurred and distorted vision recently.
# Doctor Diagnosis (round 2): Diabetes mellitus
# Similarity (round 2): 0.7888775053383126
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any numbness or tingling in your hands or feet?
# Patient Answer (round 3): No, I have not noticed any numbness or tingling in my hands or feet.
# Doctor Diagnosis (round 3): Diabetes mellitus
# Similarity (round 3): 0.7888775053383126
#
# ====== Start Case 14 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your heart rate, such as feeling your heart racing or beating irregularly?
# Patient Answer (round 1): Yes, I have noticed my heart racing occasionally, and it feels alarming at times.
# Doctor Diagnosis (round 1): Hyperthyroidism
# Similarity (round 1): 1.0000000000000004
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any tremors or shakiness in your hands recently?
# Patient Answer (round 2): No, I have not noticed any tremors or shakiness in my hands recently.
# Doctor Diagnosis (round 2): Hyperthyroidism
# Similarity (round 2): 1.0000000000000004
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced increased sensitivity to heat or found yourself feeling unusually warm compared to others?
# Patient Answer (round 3): No, I have not noticed increased sensitivity to heat or feeling unusually warm compared to others.
# Doctor Diagnosis (round 3): Hyperthyroidism
# Similarity (round 3): 1.0000000000000004
#
# ====== Start Case 15 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your bowel movements, such as constipation, diarrhea, or inability to pass gas?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Gastric outlet obstruction
# Similarity (round 1): 0.23519940492808844
#
# --- Round 2 ---
# Doctor Question (round 2): Have you had any episodes of fever, chills, or sweating along with your symptoms?
# Patient Answer (round 2): No, I have not noticed any episodes of fever, chills, or sweating along with my symptoms.
# Doctor Diagnosis (round 2): Gastric outlet obstruction
# Similarity (round 2): 0.23519940492808844
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any yellowing of your skin or eyes recently?
# Patient Answer (round 3): Yes, I have noticed a yellowish discoloration of my skin and eyes.
# Doctor Diagnosis (round 3): Acute hepatitis
# Similarity (round 3): 0.5853488307690698
#
# ====== Start Case 16 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any unintentional weight loss or changes in your bowel movements during this time?
# Patient Answer (round 1): No, I have not noticed any unintentional weight loss or changes in my bowel movements during this time.
# Doctor Diagnosis (round 1): Dyspepsia
# Similarity (round 1): 0.5396108700178115
#
# --- Round 2 ---
# Doctor Question (round 2): Are you experiencing any pain or discomfort in your abdomen, and if so, can you describe its location and severity?
# Patient Answer (round 2): No, I have not noticed any pain or discomfort in my abdomen.
# Doctor Diagnosis (round 2): Functional dyspepsia
# Similarity (round 2): 0.5995259141972334
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any recent fevers, chills, or night sweats?
# Patient Answer (round 3): No, I have not noticed any recent fevers, chills, or night sweats.
# Doctor Diagnosis (round 3): Dyspepsia
# Similarity (round 3): 0.5396108700178115
#
# ====== Start Case 17 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in the color of your stools, such as pale or clay-colored stools, recently?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Acute hepatitis B
# Similarity (round 1): 0.7878494690641089
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any itching of your skin recently?
# Patient Answer (round 2): Yes, I have been experiencing persistent itching of my skin recently.
# Doctor Diagnosis (round 2): Acute hepatitis B
# Similarity (round 2): 0.7878494690641089
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any nausea or vomiting along with your other symptoms?
# Patient Answer (round 3): No, I have not noticed any nausea or vomiting along with my other symptoms.
# Doctor Diagnosis (round 3): Acute viral hepatitis B
# Similarity (round 3): 0.7855012265903276
#
# ====== Start Case 18 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any fever, neck stiffness, or sensitivity to light along with your other symptoms?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Viral gastroenteritis
# Similarity (round 1): 0.2708373443419641
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any recent changes in your appetite or weight?
# Patient Answer (round 2): I have not noticed any recent changes in my appetite or weight.
# Doctor Diagnosis (round 2): Viral gastroenteritis
# Similarity (round 2): 0.2708373443419641
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent travel, contact with sick individuals, or changes in your environment?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Viral gastroenteritis
# Similarity (round 3): 0.2708373443419641
#
# ====== Start Case 19 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any sores or cuts that take longer than usual to heal?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Diabetes mellitus
# Similarity (round 1): 0.7888775053383126
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced increased thirst or found yourself drinking more fluids than usual recently?
# Patient Answer (round 2): Yes, I have noticed that I am waking up multiple times at night to use the bathroom, which suggests I might be drinking more fluids than usual.
# Doctor Diagnosis (round 2): Diabetes mellitus
# Similarity (round 2): 0.7888775053383126
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any numbness or tingling in your hands or feet?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Diabetes Mellitus
# Similarity (round 3): 0.7448337487182572
#
# ====== Start Case 20 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed if your symptoms, such as fatigue, anxiety, or palpitations, occur or worsen after going for long periods without eating?
# Patient Answer (round 1): Yes, I have noticed that my symptoms, such as fatigue, anxiety, and palpitations, seem to worsen after going for long periods without eating.
# Doctor Diagnosis (round 1): Hypoglycemia
# Similarity (round 1): 1.0000000000000004
#
# --- Round 2 ---
# Doctor Question (round 2): Have you ever experienced sweating, shakiness, or dizziness along with your other symptoms?
# Patient Answer (round 2): Yes, I have experienced episodes of sweating along with my other symptoms.
# Doctor Diagnosis (round 2): Hypoglycemia
# Similarity (round 2): 1.0000000000000004
#
# --- Round 3 ---
# Doctor Question (round 3): When your symptoms occur, have you ever checked your blood sugar levels or noticed if eating or drinking something sugary helps relieve them?
# Patient Answer (round 3): I have not checked my blood sugar levels, but I have experienced excessive hunger that seems unmanageable. I have not noticed if eating or drinking something sugary helps relieve my symptoms.
# Doctor Diagnosis (round 3): Hypoglycemia
# Similarity (round 3): 1.0000000000000004
#
# ====== Start Case 21 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Can you describe exactly where in your abdomen the pain is located and whether it has moved or changed in character since it started?
# Patient Answer (round 1): I have been experiencing increasing abdominal pain, but I haven't specified exactly where in my abdomen it is located or whether it has moved or changed in character since it started.
# Doctor Diagnosis (round 1): Acute pancreatitis
# Similarity (round 1): 0.47881585654123604
#
# --- Round 2 ---
# Doctor Question (round 2): Have you noticed any changes in your bowel movements, such as diarrhea, constipation, or blood in your stool?
# Patient Answer (round 2): No, I have not noticed any changes in my bowel movements, such as diarrhea, constipation, or blood in my stool.
# Doctor Diagnosis (round 2): Viral gastroenteritis
# Similarity (round 2): 0.31200644403411254
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently experienced any fever, chills, or night sweats?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Viral gastroenteritis
# Similarity (round 3): 0.31200644403411254
#
# ====== Start Case 22 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any blood in your vomit or stool during these episodes?
# Patient Answer (round 1): I have not noticed any blood in my vomit or stool during these episodes.
# Doctor Diagnosis (round 1): Gastroenteritis
# Similarity (round 1): 0.42393219620881895
#
# --- Round 2 ---
# Doctor Question (round 2): Can you tell me if your abdominal pain is constant or does it come and go?
# Patient Answer (round 2): The abdominal pain I experience comes and goes.
# Doctor Diagnosis (round 2): Gastroenteritis
# Similarity (round 2): 0.42393219620881895
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently eaten any food or traveled anywhere unusual before these symptoms started?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Gastroenteritis
# Similarity (round 3): 0.42393219620881895
#
# ====== Start Case 23 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any darkening of your urine or lightening of your stools recently?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Alcoholic hepatitis
# Similarity (round 1): 0.9306297452352394
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any itching of your skin along with the yellow discoloration?
# Patient Answer (round 2): No, I have not noticed any itching of my skin along with the yellow discoloration.
# Doctor Diagnosis (round 2): Alcoholic hepatitis
# Similarity (round 2): 0.9306297452352394
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any pain or discomfort in your abdomen, particularly in the upper right side?
# Patient Answer (round 3): No, I have not noticed any specific pain or discomfort in my abdomen, particularly in the upper right side.
# Doctor Diagnosis (round 3): Alcoholic hepatitis
# Similarity (round 3): 0.9306297452352394
#
# ====== Start Case 24 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your vision, such as blurred vision, double vision, or loss of vision, during your headaches?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Migraine
# Similarity (round 1): 0.3241283223691764
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any sensitivity to light or sound during your headaches?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Tension-type headache
# Similarity (round 2): 0.3451517769917779
#
# --- Round 3 ---
# Doctor Question (round 3): Do your headaches tend to occur at a specific time of day or are they random?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Tension-type headache
# Similarity (round 3): 0.3451517769917779
#
# ====== Start Case 25 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any increased thirst or dryness in your mouth recently?
# Patient Answer (round 1): Yes, I have noticed increased thirst.
# Doctor Diagnosis (round 1): Type 2 Diabetes Mellitus
# Similarity (round 1): 0.6632801523895875
#
# --- Round 2 ---
# Doctor Question (round 2): Have you had any changes in your vision, such as blurred vision or difficulty focusing?
# Patient Answer (round 2): Yes, I have noticed episodes of blurred and distorted vision, especially after eating.
# Doctor Diagnosis (round 2): Type 2 Diabetes Mellitus
# Similarity (round 2): 0.6632801523895875
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any numbness or tingling in your hands or feet?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Type 2 Diabetes Mellitus
# Similarity (round 3): 0.6632801523895875
#
# ====== Start Case 26 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently traveled to any regions where infectious diseases such as malaria, dengue, or typhoid are common?
# Patient Answer (round 1): No, I have not mentioned any recent travel to regions where infectious diseases such as malaria, dengue, or typhoid are common.
# Doctor Diagnosis (round 1): Influenza
# Similarity (round 1): 0.47792961305694104
#
# --- Round 2 ---
# Doctor Question (round 2): Have you been in close contact with anyone who has been ill with similar symptoms recently?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Influenza
# Similarity (round 2): 0.47792961305694104
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any rash, unusual bruising, or changes in your skin since your symptoms began?
# Patient Answer (round 3): Yes, I have noticed a skin rash with red spots spreading across my body since my symptoms began.
# Doctor Diagnosis (round 3): Dengue fever
# Similarity (round 3): 0.9002736794371207
#
# ====== Start Case 27 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your menstrual periods, such as heavier bleeding or increased frequency, over the past six months?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Iron deficiency anemia
# Similarity (round 1): 0.23121473916182483
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any unusual bleeding from your gums or nose recently?
# Patient Answer (round 2): I have not noticed any unusual bleeding from my gums or nose recently.
# Doctor Diagnosis (round 2): Iron deficiency anemia
# Similarity (round 2): 0.23121473916182483
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent infections, fevers, or unexplained weight loss?
# Patient Answer (round 3): No, I have not noticed any recent infections, fevers, or unexplained weight loss.
# Doctor Diagnosis (round 3): Iron deficiency anemia
# Similarity (round 3): 0.23121473916182483
#
# ====== Start Case 28 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently traveled to any countries where malaria or other infectious diseases are common?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Influenza
# Similarity (round 1): 0.47792961305694104
#
# --- Round 2 ---
# Doctor Question (round 2): Have you been in close contact with anyone who has been ill recently?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Influenza
# Similarity (round 2): 0.47792961305694104
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any cough, difficulty breathing, or chest pain?
# Patient Answer (round 3): No, I have not noticed any cough, difficulty breathing, or chest pain.
# Doctor Diagnosis (round 3): Influenza
# Similarity (round 3): 0.47792961305694104
#
# ====== Start Case 29 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your bowel movements, such as diarrhea, constipation, or blood in your stool?
# Patient Answer (round 1): No, I have not noticed any changes in my bowel movements, such as diarrhea, constipation, or blood in my stool.
# Doctor Diagnosis (round 1): Gastric cancer
# Similarity (round 1): 0.4879843895225333
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any unintentional weight loss over the past few weeks?
# Patient Answer (round 2): Yes, I have noticed a significant loss of appetite and have been eating much less than usual, which may have contributed to unintentional weight loss.
# Doctor Diagnosis (round 2): Gastric cancer
# Similarity (round 2): 0.4879843895225333
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any episodes of nausea or vomiting in the past three weeks?
# Patient Answer (round 3): No, I have not noticed any episodes of nausea or vomiting in the past three weeks.
# Doctor Diagnosis (round 3): Gastric cancer
# Similarity (round 3): 0.4879843895225333
#
# ====== Start Case 30 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any yellowing of your skin or eyes recently?
# Patient Answer (round 1): Yes, I have noticed a yellowish tint to my skin and eyes recently.
# Doctor Diagnosis (round 1): Acute alcoholic hepatitis
# Similarity (round 1): 0.7996031676296127
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any changes in the color of your urine or stools?
# Patient Answer (round 2): I have not noticed any changes in the color of my urine or stools.
# Doctor Diagnosis (round 2): Acute alcoholic hepatitis
# Similarity (round 2): 0.7996031676296127
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent episodes of confusion, difficulty concentrating, or unusual sleepiness?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Acute alcoholic hepatitis
# Similarity (round 3): 0.7996031676296127
#
# ====== Start Case 31 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any rash, joint swelling, or sore throat since your symptoms began?
# Patient Answer (round 1): No, I have not noticed any rash, joint swelling, or sore throat since my symptoms began.
# Doctor Diagnosis (round 1): Influenza
# Similarity (round 1): 0.42507504398190676
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any headaches or sensitivity to light since your symptoms started?
# Patient Answer (round 2): No, I have not noticed that.
# Doctor Diagnosis (round 2): Influenza
# Similarity (round 2): 0.42507504398190676
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent difficulty breathing or experienced any chest discomfort?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Influenza
# Similarity (round 3): 0.42507504398190676
#
# ====== Start Case 32 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Can you describe the visual disturbances you are experiencing, including when they occur and what you see?
# Patient Answer (round 1): I have been experiencing episodes of visual disturbances that leave me feeling unsettled. These occur during my recurrent headaches, which sometimes culminate in feelings of blurred and distorted vision.
# Doctor Diagnosis (round 1): Migraine
# Similarity (round 1): 0.9999999999999997
#
# --- Round 2 ---
# Doctor Question (round 2): Have you noticed any other symptoms accompanying your headaches, such as nausea, sensitivity to light or sound, or changes in your speech?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Migraine
# Similarity (round 2): 0.9999999999999997
#
# --- Round 3 ---
# Doctor Question (round 3): Have you observed any specific triggers or patterns that seem to bring on your headaches or visual disturbances?
# Patient Answer (round 3): I have not noticed any specific triggers or patterns that seem to bring on my headaches or visual disturbances.
# Doctor Diagnosis (round 3): Migraine
# Similarity (round 3): 0.9999999999999997
#
# ====== Start Case 33 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently traveled to any areas where you might have been exposed to infectious diseases, or have you had any contact with people who were sick?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Viral hepatitis
# Similarity (round 1): 0.6404800463572295
#
# --- Round 2 ---
# Doctor Question (round 2): Have you noticed any rashes, swelling, or changes in the color of your skin or eyes?
# Patient Answer (round 2): Yes, I have noticed yellowing of my skin and eyes.
# Doctor Diagnosis (round 2): Acute viral hepatitis
# Similarity (round 2): 0.6065631755868636
#
# --- Round 3 ---
# Doctor Question (round 3): When did you first observe the yellowing of your skin and eyes?
# Patient Answer (round 3): I first noticed the yellowing of my skin and eyes during the past week, around the same time my other symptoms worsened.
# Doctor Diagnosis (round 3): Acute hepatitis
# Similarity (round 3): 0.6161634273537847
#
# ====== Start Case 34 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any yellowing of your skin or eyes recently?
# Patient Answer (round 1): Yes, I have noticed that my skin and the whites of my eyes have turned a yellowish tint.
# Doctor Diagnosis (round 1): Acute hepatitis
# Similarity (round 1): 0.5939498041329587
#
# --- Round 2 ---
# Doctor Question (round 2): Have you recently experienced any abdominal pain or discomfort, particularly in the upper right side of your abdomen?
# Patient Answer (round 2): Yes, I have been experiencing persistent abdominal pain.
# Doctor Diagnosis (round 2): Acute hepatitis
# Similarity (round 2): 0.5939498041329587
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently traveled to a different country or been exposed to anyone who was ill?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Acute hepatitis
# Similarity (round 3): 0.5939498041329587
#
# ====== Start Case 35 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any blood in your sputum or when coughing?
# Patient Answer (round 1): No, I have not noticed any blood in my sputum or when coughing.
# Doctor Diagnosis (round 1): Pneumonia
# Similarity (round 1): 0.9999999999999999
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any recent weight loss or loss of appetite?
# Patient Answer (round 2): No, I have not noticed any recent weight loss or loss of appetite.
# Doctor Diagnosis (round 2): Pneumonia
# Similarity (round 2): 0.9999999999999999
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent exposure to individuals with respiratory infections or been in crowded environments?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Pneumonia
# Similarity (round 3): 0.9999999999999999
#
# ====== Start Case 36 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any shortness of breath or difficulty breathing with your cough?
# Patient Answer (round 1): No, I have not noticed any shortness of breath or difficulty breathing with my cough.
# Doctor Diagnosis (round 1): Acute viral upper respiratory tract infection
# Similarity (round 1): 0.5268312463772622
#
# --- Round 2 ---
# Doctor Question (round 2): Have you produced any phlegm or mucus when you cough, and if so, what color is it?
# Patient Answer (round 2): Yes, I have produced phlegm when I cough.
# Doctor Diagnosis (round 2): Acute bronchitis
# Similarity (round 2): 0.48203482456326074
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any chest pain or tightness since your symptoms began?
# Patient Answer (round 3): Yes, I have been experiencing chest pain when coughing.
# Doctor Diagnosis (round 3): Acute bronchitis
# Similarity (round 3): 0.48203482456326074
#
# ====== Start Case 37 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any fever, yellowing of your skin or eyes, or dark urine since your symptoms began?
# Patient Answer (round 1): No, I have not noticed any fever, yellowing of my skin or eyes, or dark urine since my symptoms began.
# Doctor Diagnosis (round 1): Gastroenteritis
# Similarity (round 1): 0.3712550592838739
#
# --- Round 2 ---
# Doctor Question (round 2): Can you describe the location and nature of your abdominal pain, and whether it has changed since it began?
# Patient Answer (round 2): The abdominal pain is localized to my lower abdomen, and I would rate it as a 7 out of 10 in intensity. I have not noticed any change in the location or nature of the pain since it began.
# Doctor Diagnosis (round 2): Gastroenteritis
# Similarity (round 2): 0.3712550592838739
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any changes in your bowel movements, such as diarrhea, constipation, or blood in your stool?
# Patient Answer (round 3): I have not noticed any changes in my bowel movements, such as diarrhea, constipation, or blood in my stool.
# Doctor Diagnosis (round 3): Gastroenteritis
# Similarity (round 3): 0.3712550592838739
#
# ====== Start Case 38 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any blood in your sputum when you cough?
# Patient Answer (round 1): Yes, I have noticed blood in my sputum when I cough.
# Doctor Diagnosis (round 1): Pulmonary tuberculosis
# Similarity (round 1): 0.7173980483903577
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any night sweats recently?
# Patient Answer (round 2): Yes, I have been experiencing heavy sweating, especially at night.
# Doctor Diagnosis (round 2): Tuberculosis
# Similarity (round 2): 1.0000000000000007
#
# --- Round 3 ---
# Doctor Question (round 3): Have you traveled recently or been in close contact with anyone who has been ill?
# Patient Answer (round 3): I have not traveled recently or been in close contact with anyone who has been ill.
# Doctor Diagnosis (round 3): Tuberculosis
# Similarity (round 3): 1.0000000000000007
#
# ====== Start Case 39 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any swelling in your ankles or legs recently?
# Patient Answer (round 1): Yes, I have noticed swelling in my legs recently.
# Doctor Diagnosis (round 1): Chronic kidney disease
# Similarity (round 1): 0.23401522145021375
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any shortness of breath or difficulty breathing lately?
# Patient Answer (round 2): No, I have not noticed that.
# Doctor Diagnosis (round 2): Chronic kidney disease
# Similarity (round 2): 0.23401522145021375
#
# --- Round 3 ---
# Doctor Question (round 3): Have you observed any changes in your urination, such as frequency, color, or foaming?
# Patient Answer (round 3): I have not noticed any changes in my urination, such as frequency, color, or foaming.
# Doctor Diagnosis (round 3): Chronic venous insufficiency
# Similarity (round 3): 0.5897960963950912
#
# ====== Start Case 40 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any rash, night sweats, or recent weight loss along with your other symptoms?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Infectious mononucleosis
# Similarity (round 1): 0.37779744822781713
#
# --- Round 2 ---
# Doctor Question (round 2): Have you recently traveled anywhere or been in contact with anyone who was sick?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Infectious mononucleosis
# Similarity (round 2): 0.37779744822781713
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any shortness of breath, chest pain, or difficulty breathing since your symptoms began?
# Patient Answer (round 3): Yes, I have experienced chest pain occurring when I cough. I have not noticed any shortness of breath or difficulty breathing.
# Doctor Diagnosis (round 3): Acute bronchitis
# Similarity (round 3): 0.48203482456326074
#
# ====== Start Case 41 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently used any recreational drugs, caffeine, or new medications before your symptoms started?
# Patient Answer (round 1): No, I have not noticed using any recreational drugs, caffeine, or new medications before my symptoms started.
# Doctor Diagnosis (round 1): Hypoglycemia
# Similarity (round 1): 1.0000000000000004
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any recent stressful events or significant changes in your life that might have triggered these symptoms?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Hypoglycemia
# Similarity (round 2): 1.0000000000000004
#
# --- Round 3 ---
# Doctor Question (round 3): Have you ever had similar symptoms in the past, or is this the first time you have experienced them?
# Patient Answer (round 3): This is the first time I have experienced these symptoms.
# Doctor Diagnosis (round 3): Hypoglycemia
# Similarity (round 3): 1.0000000000000004
#
# ====== Start Case 42 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any swelling, redness, or warmth in your knees or wrists along with the joint pain?
# Patient Answer (round 1): I have not noticed any swelling, redness, or warmth in my knees or wrists along with the joint pain.
# Doctor Diagnosis (round 1): Hemochromatosis
# Similarity (round 1): 0.43512400984947674
#
# --- Round 2 ---
# Doctor Question (round 2): Can you describe the abdominal discomfort you are experiencing, such as whether it is sharp, dull, constant, or comes and goes?
# Patient Answer (round 2): I have abdominal pain that is localized in the upper right quadrant, and it intensifies after eating.
# Doctor Diagnosis (round 2): Hemochromatosis
# Similarity (round 2): 0.43512400984947674
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any yellowing of your skin or eyes recently?
# Patient Answer (round 3): Yes, I have noticed a yellowish tint to my skin and yellowing of my eyes.
# Doctor Diagnosis (round 3): Hepatitis
# Similarity (round 3): 0.6959291478188383
#
# ====== Start Case 43 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently traveled to any areas with known outbreaks of infectious diseases or been exposed to anyone who is ill?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Influenza
# Similarity (round 1): 0.42507504398190676
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any other symptoms such as nausea, vomiting, a rash, or difficulty breathing?
# Patient Answer (round 2): Yes, I have experienced nausea and vomiting. I have not noticed a rash or difficulty breathing.
# Doctor Diagnosis (round 2): Dengue fever
# Similarity (round 2): 0.5220994400895804
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any changes in your urine color or the frequency of urination since your symptoms began?
# Patient Answer (round 3): I have not noticed any changes in my urine color or the frequency of urination since my symptoms began.
# Doctor Diagnosis (round 3): Influenza
# Similarity (round 3): 0.42507504398190676
#
# ====== Start Case 44 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your menstrual periods or irregularities recently?
# Patient Answer (round 1): Yes, I have noticed changes in my menstrual periods. They have become more irregular and abnormal in flow.
# Doctor Diagnosis (round 1): Hyperthyroidism
# Similarity (round 1): 1.0000000000000004
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any tremors or shakiness in your hands?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Hyperthyroidism
# Similarity (round 2): 1.0000000000000004
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any problems with your heart, such as feeling your heart racing or pounding unexpectedly?
# Patient Answer (round 3): Yes, I have noticed episodes of my heart racing and a fast heart rate, especially during stressful situations.
# Doctor Diagnosis (round 3): Hyperthyroidism
# Similarity (round 3): 1.0000000000000004
#
# ====== Start Case 45 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you ever been diagnosed with or noticed any persistent patches of red, scaly skin on your scalp, elbows, or knees in addition to the rash on your fingers?
# Patient Answer (round 1): Yes, I have noticed a distinctive skin rash on my elbows and lower back characterized by silvery scales.
# Doctor Diagnosis (round 1): Psoriatic arthritis
# Similarity (round 1): 0.6813099839042092
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any stiffness in your joints, especially in the morning or after periods of inactivity?
# Patient Answer (round 2): No, I have not noticed any stiffness in my joints, especially in the morning or after periods of inactivity.
# Doctor Diagnosis (round 2): Psoriatic arthritis
# Similarity (round 2): 0.6813099839042092
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any changes in your fingernails or toenails, such as pitting, discoloration, or separation from the nail bed?
# Patient Answer (round 3): Yes, I have noticed small dents forming in my nails, and they have started to feel tender and inflamed.
# Doctor Diagnosis (round 3): Psoriatic arthritis
# Similarity (round 3): 0.6813099839042092
#
# ====== Start Case 46 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any pain or difficulty when urinating, or any changes in the color or frequency of your urine?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Influenza
# Similarity (round 1): 0.47792961305694104
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any chills or episodes of sweating along with your fever?
# Patient Answer (round 2): Yes, I have experienced severe chills along with my fever.
# Doctor Diagnosis (round 2): Pyelonephritis
# Similarity (round 2): 0.32412622799581176
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently traveled anywhere or been in contact with anyone who was sick?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Pyelonephritis
# Similarity (round 3): 0.32412622799581176
#
# ====== Start Case 47 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any darkening of your urine or pale stools recently?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Hepatitis
# Similarity (round 1): 0.7482187625997445
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any pain or discomfort in your abdomen, particularly on the right side?
# Patient Answer (round 2): No, I have not noticed any pain or discomfort in my abdomen, particularly on the right side.
# Doctor Diagnosis (round 2): Hepatitis
# Similarity (round 2): 0.7482187625997445
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent episodes of fever or chills?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Hepatocellular jaundice
# Similarity (round 3): 0.5114232990007874
#
# ====== Start Case 48 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any blood in your sputum or when you cough?
# Patient Answer (round 1): Yes, I have noticed blood in my sputum when I cough, which has caused me great concern.
# Doctor Diagnosis (round 1): Tuberculosis
# Similarity (round 1): 1.0000000000000007
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any chest pain or discomfort while coughing or at rest?
# ...
# Patient Answer (round 3): No, I have not noticed any fever, chills, or sweating along with my abdominal pain.
# Doctor Diagnosis (round 3): Acute pancreatitis
# Similarity (round 3): 0.47881585654123604
#
# ====== Start Case 84 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any unintentional weight loss, coughing up blood, or night sweats along with your cough?
# Patient Answer (round 1): No, I have not noticed any unintentional weight loss, coughing up blood, or night sweats along with my cough.
# Doctor Diagnosis (round 1): Chronic bronchitis
# Similarity (round 1): 0.6225919350844931
#
# --- Round 2 ---
# Doctor Question (round 2): Can you describe whether your cough is mostly dry or if you are producing any phlegm, and if so, what does it look like?
# Patient Answer (round 2): I have been producing mucoid sputum, which has been especially noticeable in the mornings.
# Doctor Diagnosis (round 2): Chronic bronchitis
# Similarity (round 2): 0.6225919350844931
#
# --- Round 3 ---
# Doctor Question (round 3): Have you experienced any wheezing, chest tightness, or shortness of breath during your daily activities?
# Patient Answer (round 3): Yes, I have experienced episodes of breathlessness during physical activity.
# Doctor Diagnosis (round 3): Chronic Obstructive Pulmonary Disease (COPD)
# Similarity (round 3): 0.4907460905907401
#
# ====== Start Case 85 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed increased thirst or are you drinking more fluids than usual?
# Patient Answer (round 1): Yes, I have noticed increased thirst and I am drinking more fluids than usual.
# Doctor Diagnosis (round 1): Diabetes mellitus
# Similarity (round 1): 0.7888775053383126
#
# --- Round 2 ---
# Doctor Question (round 2): Have you had any recent episodes of infections, such as urinary tract infections or skin infections?
# Patient Answer (round 2): No, I have not noticed any recent episodes of infections.
# Doctor Diagnosis (round 2): Diabetes mellitus
# Similarity (round 2): 0.7888775053383126
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any numbness or tingling in your hands or feet recently?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Diabetes mellitus
# Similarity (round 3): 0.7888775053383126
#
# ====== Start Case 86 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Can you describe the visual disturbances you have been experiencing, such as whether you see flashes, blurred vision, double vision, or any loss of vision?
# Patient Answer (round 1): I have been experiencing episodes of blurred and distorted vision, which occur sporadically and are often accompanied by a sense of dizziness.
# Doctor Diagnosis (round 1): Migraine
# Similarity (round 1): 0.9999999999999997
#
# --- Round 2 ---
# Doctor Question (round 2): Have you noticed if your headaches tend to occur before, during, or after the episodes of blurred and distorted vision?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Migraine
# Similarity (round 2): 0.9999999999999997
#
# --- Round 3 ---
# Doctor Question (round 3): When you experience dizziness with your visual symptoms, do you also have any nausea, vomiting, or sensitivity to light or sound?
# Patient Answer (round 3): I have not noticed any nausea, vomiting, or sensitivity to light or sound when I experience dizziness with my visual symptoms.
# Doctor Diagnosis (round 3): Migraine
# Similarity (round 3): 0.9999999999999997
#
# ====== Start Case 87 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently developed a fever or noticed any high temperatures?
# Patient Answer (round 1): Yes, I have developed a high fever reaching 103°F.
# Doctor Diagnosis (round 1): Gastroenteritis
# Similarity (round 1): 0.42393219620881895
#
# --- Round 2 ---
# Doctor Question (round 2): Can you describe the changes in your bowel habits, such as experiencing diarrhea, constipation, or any unusual color or consistency?
# Patient Answer (round 2): I have experienced constipation followed by episodes of abdominal pain and sudden diarrhea.
# Doctor Diagnosis (round 2): Typhoid fever
# Similarity (round 2): 0.9336343554982073
#
# --- Round 3 ---
# Doctor Question (round 3): Have you traveled recently or been exposed to anyone who is sick?
# Patient Answer (round 3): I deny any recent travel, though I mention ingestion of undercooked food prior to these symptoms. I have not been exposed to anyone who is sick.
# Doctor Diagnosis (round 3): Salmonella gastroenteritis
# Similarity (round 3): 0.4608815600418865
#
# ====== Start Case 88 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed if the change in your skin color is more of a yellowish tint (jaundice), or is it darker or bronzed in appearance?
# Patient Answer (round 1): I have noticed a noticeable yellowish tint to my skin and eyes.
# Doctor Diagnosis (round 1): Jaundice
# Similarity (round 1): 0.35011765964249475
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any changes in the color of your urine or stools recently?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Jaundice
# Similarity (round 2): 0.35011765964249475
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any abdominal pain, swelling, or discomfort lately?
# Patient Answer (round 3): No, I have not noticed any abdominal pain, swelling, or discomfort lately.
# Doctor Diagnosis (round 3): Jaundice
# Similarity (round 3): 0.35011765964249475
#
# ====== Start Case 89 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you recently used any drugs, medications, or substances, including over-the-counter or herbal products?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Panic attack
# Similarity (round 1): 0.3773237982211151
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any recent changes in your diet, fluid intake, or eating habits?
# Patient Answer (round 2): I have been feeling excessively hungry, which I would describe as insatiable.
# Doctor Diagnosis (round 2): Panic attack
# Similarity (round 2): 0.3773237982211151
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any changes in the amount or frequency of urination lately?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Panic attack
# Similarity (round 3): 0.3773237982211151
#
# ====== Start Case 90 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in the color of your urine or stools recently?
# Patient Answer (round 1): Yes, I have noticed that my urine has become dark.
# Doctor Diagnosis (round 1): Hepatitis
# Similarity (round 1): 0.42810795644560995
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any itching of your skin along with the yellowish discoloration?
# Patient Answer (round 2): Yes, I have experienced intense itching all over my body along with the yellowish discoloration of my skin.
# Doctor Diagnosis (round 2): Hepatitis
# Similarity (round 2): 0.42810795644560995
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently traveled to another country or been exposed to anyone with similar symptoms?
# Patient Answer (round 3): No, I have not traveled to another country or been exposed to anyone with similar symptoms.
# Doctor Diagnosis (round 3): Hepatitis
# Similarity (round 3): 0.42810795644560995
#
# ====== Start Case 91 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any swelling, numbness, or color changes in your legs along with the cramps?
# Patient Answer (round 1): Yes, I have noticed swelling in my legs along with the cramps.
# Doctor Diagnosis (round 1): Chronic venous insufficiency
# Similarity (round 1): 0.5897960963950912
#
# --- Round 2 ---
# Doctor Question (round 2): Do the leg cramps or swelling tend to get worse at certain times of day or after specific activities?
# Patient Answer (round 2): Yes, the leg cramps tend to get worse after long periods of sitting.
# Doctor Diagnosis (round 2): Chronic venous insufficiency
# Similarity (round 2): 0.5897960963950912
#
# --- Round 3 ---
# Doctor Question (round 3): Have you ever experienced shortness of breath, chest discomfort, or a rapid heartbeat along with your leg symptoms?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Chronic venous insufficiency
# Similarity (round 3): 0.5897960963950912
#
# ====== Start Case 92 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in your skin or hair, such as dryness or thinning?
# Patient Answer (round 1): No, I have not noticed any changes in my skin or hair, such as dryness or thinning.
# Doctor Diagnosis (round 1): Hypothyroidism
# Similarity (round 1): 0.9999999999999998
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any constipation or changes in your bowel habits recently?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Hypothyroidism
# Similarity (round 2): 0.9999999999999998
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any difficulty with memory, concentration, or feeling unusually forgetful lately?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Hypothyroidism
# Similarity (round 3): 0.9999999999999998
#
# ====== Start Case 93 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Can you describe what the rash looks like and where on your body it first appeared?
# Patient Answer (round 1): The rash consists of scattered red spots that are visible over my body. I don't recall exactly where it first appeared, but it has spread widely since then.
# Doctor Diagnosis (round 1): Viral exanthem
# Similarity (round 1): 0.4113911525842236
#
# --- Round 2 ---
# Doctor Question (round 2): Have you traveled recently or been in contact with anyone who had a similar rash or was ill?
# Patient Answer (round 2): I have not traveled recently, and I have not been in contact with anyone who had a similar rash or was ill.
# Doctor Diagnosis (round 2): Viral exanthem
# Similarity (round 2): 0.4113911525842236
#
# --- Round 3 ---
# Doctor Question (round 3): Have you started any new medications, foods, or personal care products in the days before the rash appeared?
# Patient Answer (round 3): No, I have not noticed starting any new medications, foods, or personal care products in the days before the rash appeared.
# Doctor Diagnosis (round 3): Viral exanthem
# Similarity (round 3): 0.4113911525842236
#
# ====== Start Case 94 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you experienced any fever, sensitivity to light, or nausea along with your stiff neck and headaches?
# Patient Answer (round 1): No, I have not noticed any fever, sensitivity to light, or nausea along with my stiff neck and headaches.
# Doctor Diagnosis (round 1): Tension-type headache
# Similarity (round 1): 0.536368738127347
#
# --- Round 2 ---
# Doctor Question (round 2): Have you noticed any recent changes in your bowel movements or appetite since these symptoms began?
# Patient Answer (round 2): I have noticed excessive hunger, feeling the need to eat more frequently without satisfaction. However, there are no specific details about changes in my bowel movements.
# Doctor Diagnosis (round 2): Tension-type headache
# Similarity (round 2): 0.536368738127347
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent weight changes or noticed swelling in any part of your body?
# Patient Answer (round 3): I have not noticed any recent weight changes or swelling in any part of my body.
# Doctor Diagnosis (round 3): Tension-type headache
# Similarity (round 3): 0.536368738127347
#
# ====== Start Case 95 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any recent travel, changes in your diet, or contact with anyone who has been ill?
# Patient Answer (round 1): I have not noticed any recent travel, changes in my diet, or contact with anyone who has been ill.
# Doctor Diagnosis (round 1): Viral gastroenteritis
# Similarity (round 1): 0.5156293597900578
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any rash, swelling, or redness around your joints or elsewhere on your body?
# Patient Answer (round 2): No, I have not noticed any rash, swelling, or redness around my joints or elsewhere on my body.
# Doctor Diagnosis (round 2): Viral gastroenteritis
# Similarity (round 2): 0.5156293597900578
#
# --- Round 3 ---
# Doctor Question (round 3): Have you recently started taking any new medications or supplements?
# Patient Answer (round 3): No, I have not noticed that.
# Doctor Diagnosis (round 3): Viral gastroenteritis
# Similarity (round 3): 0.5156293597900578
#
# ====== Start Case 96 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in the color of your urine or stools recently?
# Patient Answer (round 1): I have not noticed that.
# Doctor Diagnosis (round 1): Alcoholic liver cirrhosis
# Similarity (round 1): 0.7915122036850998
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any nausea or vomiting along with your abdominal discomfort?
# Patient Answer (round 2): No, I have not noticed any nausea or vomiting along with my abdominal discomfort.
# Doctor Diagnosis (round 2): Alcoholic liver cirrhosis
# Similarity (round 2): 0.7915122036850998
#
# --- Round 3 ---
# Doctor Question (round 3): Have you observed any recent loss of appetite or unintentional weight loss?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Alcoholic liver cirrhosis
# Similarity (round 3): 0.7915122036850998
#
# ====== Start Case 97 ======
#
# --- Round 1 ---
# Doctor Question (round 1): What brings you in to see me today?
# Patient Answer (round 1): I have not provided any details or symptoms.
# Doctor Diagnosis (round 1): No diagnosis
# Similarity (round 1): 0.3204189103007897
#
# --- Round 2 ---
# Doctor Question (round 2): Can you describe any changes in your health or how you’ve been feeling recently?
# Patient Answer (round 2): No.
# Doctor Diagnosis (round 2): No diagnosis
# Similarity (round 2): 0.3204189103007897
#
# --- Round 3 ---
# Doctor Question (round 3): Have you noticed any discomfort, pain, or unusual sensations in your body lately?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): No disease detected
# Similarity (round 3): 0.3541896510481542
#
# ====== Start Case 98 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed any changes in the color of your stools, such as them becoming pale or clay-colored?
# Patient Answer (round 1): No, I have not noticed that.
# Doctor Diagnosis (round 1): Viral hepatitis
# Similarity (round 1): 0.6404800463572295
#
# --- Round 2 ---
# Doctor Question (round 2): Have you recently traveled out of the country or been exposed to anyone who is ill?
# Patient Answer (round 2): I have not noticed that.
# Doctor Diagnosis (round 2): Acute viral hepatitis
# Similarity (round 2): 0.6065631755868636
#
# --- Round 3 ---
# Doctor Question (round 3): Have you taken any new medications, supplements, or over-the-counter remedies in the past month?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Acute viral hepatitis
# Similarity (round 3): 0.6065631755868636
#
# ====== Start Case 99 ======
#
# --- Round 1 ---
# Doctor Question (round 1): Have you noticed an increase in the frequency or volume of urination recently?
# Patient Answer (round 1): Yes, I have noticed an increase in the frequency and volume of urination recently.
# Doctor Diagnosis (round 1): Type 2 Diabetes Mellitus
# Similarity (round 1): 0.6632801523895875
#
# --- Round 2 ---
# Doctor Question (round 2): Have you experienced any episodes of numbness or tingling in your hands or feet?
# Patient Answer (round 2): No, I have not noticed any episodes of numbness or tingling in my hands or feet.
# Doctor Diagnosis (round 2): Type 2 Diabetes Mellitus
# Similarity (round 2): 0.6632801523895875
#
# --- Round 3 ---
# Doctor Question (round 3): Have you had any recent infections or slow-healing wounds?
# Patient Answer (round 3): I have not noticed that.
# Doctor Diagnosis (round 3): Type 2 Diabetes Mellitus
# Similarity (round 3): 0.6632801523895875
